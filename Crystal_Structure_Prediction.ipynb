# %% [markdown]
# # Imports

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import datasets
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from random import randint
import pandas as pd
import numpy as np

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset

# %%
DATA_URL = 'data/Crystal_structure.csv'

# %%
unprocessed_data = pd.read_csv(DATA_URL)
data = pd.read_csv(DATA_URL)
data.count()
# Out:
# Compound             5329
# A                    5329
# B                    5329
# In literature        5329
# v(A)                 5329
# v(B)                 5329
# r(AXII)(Å)           5329
# r(AVI)(Å)            5329
# r(BVI)(Å)            5329
# EN(A)                5329
# EN(B)                5329
# l(A-O)(Å)            5329
# l(B-O)(Å)            5329
# ΔENR                 5329
# tG                   5329
# τ                    5329
# μ                    5329
# Lowest distortion    5329
# dtype: int64

# %%
data.head()
# Out:
#   Compound   A   B  In literature v(A) v(B)  r(AXII)(Å)  r(AVI)(Å)  r(BVI)(Å)  \
# 0    Ac2O3  Ac  Ac          False    0    0        1.12       1.12       1.12
# 1   AcAgO3  Ac  Ag          False    0    0        1.12       1.12       0.95
# 2   AcAlO3  Ac  Al          False    0    0        1.12       1.12       0.54
# 3   AcAsO3  Ac  As          False    0    0        1.12       1.12       0.52
# 4   AcAuO3  Ac  Au          False    0    0        1.12       1.12       0.93
#
#    EN(A)  EN(B)  l(A-O)(Å)  l(B-O)(Å)      ΔENR        tG  τ         μ  \
# 0    1.1   1.10        0.0   0.000000 -3.248000  0.707107  -  0.800000
# 1    1.1   1.93        0.0   2.488353 -2.565071  0.758259  -  0.678571
# 2    1.1   1.61        0.0   1.892894 -1.846714  0.918510  -  0.385714
# 3    1.1   2.18        0.0   1.932227 -1.577429  0.928078  -  0.371429
# 4    1.1   2.54        0.0   2.313698 -2.279786  0.764768  -  0.664286
#
#   Lowest distortion
# 0             cubic
# 1      orthorhombic
# 2             cubic
# 3      orthorhombic
# 4      orthorhombic

# %% [markdown]
# # Data cleaning and pre-processing

# %% [markdown]
# ## Unnecessary features
#
# The "present in literature" field should not be determinant of the crystal structure.

# %%
data = data.drop(["In literature"], axis=1)
data.columns
# Out:
# Index(['Compound', 'A', 'B', 'v(A)', 'v(B)', 'r(AXII)(Å)', 'r(AVI)(Å)',
#        'r(BVI)(Å)', 'EN(A)', 'EN(B)', 'l(A-O)(Å)', 'l(B-O)(Å)', 'ΔENR', 'tG',
#        'τ', 'μ', 'Lowest distortion'],
#       dtype='object')

# %% [markdown]
# Likewise, the name of the compound should not be fed to the model. Plus, the information in the name is already contained in the `A` and `B` fields. The compound name is always `AB` followed by `O3`

# %%
data = data.drop(["Compound"], axis=1)
data.columns
# Out:
# Index(['A', 'B', 'v(A)', 'v(B)', 'r(AXII)(Å)', 'r(AVI)(Å)', 'r(BVI)(Å)',
#        'EN(A)', 'EN(B)', 'l(A-O)(Å)', 'l(B-O)(Å)', 'ΔENR', 'tG', 'τ', 'μ',
#        'Lowest distortion'],
#       dtype='object')

# %% [markdown]
# ## Dash pre-processing

# %%
(data == "-").any()
# Out:
# A                    False
# B                    False
# v(A)                  True
# v(B)                  True
# r(AXII)(Å)           False
# r(AVI)(Å)            False
# r(BVI)(Å)            False
# EN(A)                False
# EN(B)                False
# l(A-O)(Å)            False
# l(B-O)(Å)            False
# ΔENR                 False
# tG                   False
# τ                     True
# μ                    False
# Lowest distortion     True
# dtype: bool

# %% [markdown]
# ### Valencies `v(A)` and `v(B)`

# %%
print(data["v(A)"].unique())
print(data["v(B)"].unique())
# Out:
# ['0' '-' '1' '3' '2' '4' '5']
# ['0' '-' '5' '3' '4' '2' '1']

# %%
(data["v(A)"] == "-").sum(), (data["v(B)"] == "-").sum()
# Out:
# (1881, 1881)

# %%
((data["v(A)"] == "-").sum() and (data["v(B)"] == "-").sum()).sum()
# Out:
# 1881

# %%
data = data.drop(data[data["v(A)"] == "-"].index)
data = data.drop(data[data["v(B)"] == "-"].index)

# %%
valency_a_one_hot = pd.get_dummies(data['v(A)'], prefix="v(A)=", prefix_sep="")
valency_b_one_hot = pd.get_dummies(data['v(B)'], prefix="v(B)=", prefix_sep="")
data = pd.concat([data, valency_a_one_hot, valency_b_one_hot], axis=1)

# %% [markdown]
# Now the dataframe has the valencies one-hot encoded and we can safely drop the original columns

# %%
data = data.drop(["v(A)"], axis=1)
data = data.drop(["v(B)"], axis=1)
data.columns
# Out:
# Index(['A', 'B', 'r(AXII)(Å)', 'r(AVI)(Å)', 'r(BVI)(Å)', 'EN(A)', 'EN(B)',
#        'l(A-O)(Å)', 'l(B-O)(Å)', 'ΔENR', 'tG', 'τ', 'μ', 'Lowest distortion',
#        'v(A)=0', 'v(A)=1', 'v(A)=2', 'v(A)=3', 'v(A)=4', 'v(A)=5', 'v(B)=0',
#        'v(B)=1', 'v(B)=2', 'v(B)=3', 'v(B)=4', 'v(B)=5'],
#       dtype='object')

# %%
len(data["τ"].unique())
# Out:
# 1608

# %%
data = data.drop(["τ"], axis=1)
data.columns
# Out:
# Index(['A', 'B', 'r(AXII)(Å)', 'r(AVI)(Å)', 'r(BVI)(Å)', 'EN(A)', 'EN(B)',
#        'l(A-O)(Å)', 'l(B-O)(Å)', 'ΔENR', 'tG', 'μ', 'Lowest distortion',
#        'v(A)=0', 'v(A)=1', 'v(A)=2', 'v(A)=3', 'v(A)=4', 'v(A)=5', 'v(B)=0',
#        'v(B)=1', 'v(B)=2', 'v(B)=3', 'v(B)=4', 'v(B)=5'],
#       dtype='object')

# %% [markdown]
# ### Target `Lowest distortion`
#
# This is the target field so any pre-processing could be bad for accuracy of the model we want to develop. Since the dash `-` it's only present in 53 rows we could safely remove these rows from the dataset, as it's approximately a 1% of the data.

# %%
(data["Lowest distortion"] == "-").sum()
# Out:
# 22

# %% [markdown]
# ## Change categorical data into numerical
# Here comes again the one-hot encoding. The fields where this is necessary are `A` and `B`, which show the first and second elements in the compound.
# The target `Lowest distortion` is also categorical but must be encoded to integer values

# %% [markdown]
# ### Features

# %%
a_one_hot = pd.get_dummies(data['A'], prefix="A=", prefix_sep="")
b_one_hot = pd.get_dummies(data['B'], prefix="B=", prefix_sep="")
data = pd.concat([data, a_one_hot, b_one_hot], axis=1)

# %%
data = data.drop(["A"], axis=1)
data = data.drop(["B"], axis=1)

# %% [markdown]
# ### Target `Lowest distortion`

# %%
unknown_data = data[data["Lowest distortion"] == "-"]
data = data.drop(data[data["Lowest distortion"] == "-"].index)

# %%
class_names = data["Lowest distortion"].unique()
class_names
# Out:
# array(['cubic', 'orthorhombic', 'rhombohedral', 'tetragonal'],
#       dtype=object)

# %%
data["Lowest distortion"] = data["Lowest distortion"].astype('category')
data["Lowest distortion"] = data["Lowest distortion"].cat.codes

# %% [markdown]
# ## Split the train/test/unknown data

# %%
len(data), len(unknown_data)
# Out:
# (3426, 22)

# %%
features = data.drop(labels=["Lowest distortion"], axis=1)
target = data["Lowest distortion"]

# %%
SEED = 0
X_temp, X_test, y_temp, y_test = train_test_split(features, target, test_size=0.2, random_state=SEED)
X_train, X_val, y_train, y_val = train_test_split(X_temp, y_temp, test_size=0.25, random_state=SEED)

# %% [markdown]
# ## Preprocessed dataset

# %%
data
# Out:
#       r(AXII)(Å)  r(AVI)(Å)  r(BVI)(Å)  EN(A)  EN(B)  l(A-O)(Å)  l(B-O)(Å)  \
# 0           1.12       1.12       1.12   1.10   1.10    0.00000   0.000000
# 1           1.12       1.12       0.95   1.10   1.93    0.00000   2.488353
# 2           1.12       1.12       0.54   1.10   1.61    0.00000   1.892894
# 3           1.12       1.12       0.52   1.10   2.18    0.00000   1.932227
# 4           1.12       1.12       0.93   1.10   2.54    0.00000   2.313698
# ...          ...        ...        ...    ...    ...        ...        ...
# 5316        0.89       0.72       0.60   1.33   1.90    2.38342   0.000000
# 5319        0.89       0.72       0.61   1.33   1.54    2.38342   1.927849
# 5322        0.89       0.72       0.76   1.33   1.38    2.38342   2.047800
# 5323        0.89       0.72       0.54   1.33   1.63    2.38342   1.758039
# 5324        0.89       0.72       0.62   1.33   2.36    2.38342   1.745600
#
#           ΔENR        tG         μ  ...   B=Ti   B=Tl   B=Tm    B=U    B=V  \
# 0    -3.248000  0.707107  0.800000  ...  False  False  False  False  False
# 1    -2.565071  0.758259  0.678571  ...  False  False  False  False  False
# 2    -1.846714  0.918510  0.385714  ...  False  False  False  False  False
# 3    -1.577429  0.928078  0.371429  ...  False  False  False  False  False
# 4    -2.279786  0.764768  0.664286  ...  False  False  False  False  False
# ...        ...       ...       ...  ...    ...    ...    ...    ...    ...
# 5316 -1.678786  0.809637  0.428571  ...  False  False  False  False  False
# 5319 -1.813036  0.805609  0.435714  ...   True  False  False  False  False
# 5322 -2.161214  0.749664  0.542857  ...  False  False  False   True  False
# 5323 -1.645679  0.834678  0.385714  ...  False  False  False  False   True
# 5324 -1.572214  0.801621  0.442857  ...  False  False  False  False  False
#
#         B=W    B=Y   B=Yb   B=Zn   B=Zr
# 0     False  False  False  False  False
# 1     False  False  False  False  False
# 2     False  False  False  False  False
# 3     False  False  False  False  False
# 4     False  False  False  False  False
# ...     ...    ...    ...    ...    ...
# 5316  False  False  False  False  False
# 5319  False  False  False  False  False
# 5322  False  False  False  False  False
# 5323  False  False  False  False  False
# 5324   True  False  False  False  False
#
# [3426 rows x 169 columns]

# %% [markdown]
# # Random Forest algorithm

# %%
forest = RandomForestClassifier(n_estimators=1000, random_state=SEED, verbose=1)
forest = forest.fit(X_train, y_train)
forest.verbose = 0 # silence further control msg
# Out:
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=1)]: Done 449 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=1)]: Done 799 tasks      | elapsed:   10.5s

# %%
accuracy = round(forest.score(X_test, y_test) * 100, 2)
print(f"Accuracy of the random forest: {accuracy}%")
# Out:
# Accuracy of the random forest: 81.92%

# %% [markdown]
# # Deep neural net approach

# %%
# Assuming X_train, y_train, X_test, y_test are already defined
# Convert numpy arrays to PyTorch tensors
X_train_tensor = torch.tensor(X_train.values.tolist(), dtype=torch.float32)
y_train_tensor = torch.tensor(y_train.values, dtype=torch.long)
X_test_tensor = torch.tensor(X_test.values.tolist(), dtype=torch.float32)
y_test_tensor = torch.tensor(y_test.values, dtype=torch.long)
X_val_tensor = torch.tensor(X_val.values.tolist(),dtype=torch.float32)
y_val_tensor = torch.tensor(y_val.values, dtype=torch.long)


# Create DataLoader for training, validation, and testing
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
val_dataset = TensorDataset(X_val_tensor, y_val_tensor)
test_dataset = TensorDataset(X_test_tensor, y_test_tensor)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# Define the PyTorch model
class Net(nn.Module):
    def __init__(self, input_size, hidden_size1=300, hidden_size2=200, hidden_size3=100, output_size=4):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size1)
        self.fc2 = nn.Linear(hidden_size1, hidden_size2)
        self.fc3 = nn.Linear(hidden_size2, hidden_size3)
        self.fc4 = nn.Linear(hidden_size3, output_size)
        self.dropout = nn.Dropout(0.4)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        x = F.relu(self.fc2(x))
        x = self.dropout(x)
        x = F.relu(self.fc3(x))
        x = self.dropout(x)
        x = self.fc4(x)
        return F.log_softmax(x, dim=1)

# Instantiate the model
INPUT_SHAPE = X_train.shape[1]
model = Net(INPUT_SHAPE)

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0005)

# Training loop with validation
num_epochs = 100
best_val_acc = 0.0
save_path = 'best_model.pth'

for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    running_corrects = 0
    for inputs, labels in train_loader:
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item() * inputs.size(0)
        _, preds = torch.max(outputs, 1)
        running_corrects += torch.sum(preds == labels.data)
    epoch_loss = running_loss / len(train_loader.dataset)
    epoch_acc = running_corrects.double() / len(train_loader.dataset)
    
    model.eval()
    val_loss = 0.0
    val_corrects = 0
    with torch.no_grad():
        for inputs, labels in val_loader:
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item() * inputs.size(0)
            _, preds = torch.max(outputs, 1)
            val_corrects += torch.sum(preds == labels.data)
    val_loss /= len(val_loader.dataset)
    val_acc = val_corrects.double() / len(val_loader.dataset)
    
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        torch.save(model.state_dict(), save_path)
    
    print(f'Epoch {epoch+1}/{num_epochs}, Loss: {epoch_loss:.4f}, Accuracy: {epoch_acc:.4f}, Val Loss: {val_loss:.4f}, Val Accuracy: {val_acc:.4f}')

# Load the best model for evaluation
model.load_state_dict(torch.load(save_path))
model.eval()

# Evaluate the model
test_loss = 0.0
test_corrects = 0
with torch.no_grad():
    for inputs, labels in test_loader:
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        test_loss += loss.item() * inputs.size(0)
        _, preds = torch.max(outputs, 1)
        test_corrects += torch.sum(preds == labels.data)
test_loss /= len(test_loader.dataset)
test_acc = test_corrects.double() / len(test_loader.dataset)
print(f'Test Loss: {test_loss:.4f}, Test Accuracy: {test_acc:.4f}')
# Out:
# Epoch 1/100, Loss: 1.0436, Accuracy: 0.6190, Val Loss: 0.9077, Val Accuracy: 0.6234
# Epoch 2/100, Loss: 0.9098, Accuracy: 0.6292, Val Loss: 0.8740, Val Accuracy: 0.6234
# Epoch 3/100, Loss: 0.8600, Accuracy: 0.6311, Val Loss: 0.8190, Val Accuracy: 0.6234
# Epoch 4/100, Loss: 0.8022, Accuracy: 0.6618, Val Loss: 0.8062, Val Accuracy: 0.6584
# Epoch 5/100, Loss: 0.7432, Accuracy: 0.6983, Val Loss: 0.7436, Val Accuracy: 0.6978
# Epoch 6/100, Loss: 0.6965, Accuracy: 0.7241, Val Loss: 0.7079, Val Accuracy: 0.7197
# Epoch 7/100, Loss: 0.6552, Accuracy: 0.7382, Val Loss: 0.6878, Val Accuracy: 0.7343
# Epoch 8/100, Loss: 0.6102, Accuracy: 0.7616, Val Loss: 0.6703, Val Accuracy: 0.7431
# Epoch 9/100, Loss: 0.6057, Accuracy: 0.7669, Val Loss: 0.6639, Val Accuracy: 0.7562
# Epoch 10/100, Loss: 0.5653, Accuracy: 0.7796, Val Loss: 0.6526, Val Accuracy: 0.7445
# Epoch 11/100, Loss: 0.5424, Accuracy: 0.7898, Val Loss: 0.6502, Val Accuracy: 0.7431
# Epoch 12/100, Loss: 0.5024, Accuracy: 0.8092, Val Loss: 0.6278, Val Accuracy: 0.7693
# Epoch 13/100, Loss: 0.4979, Accuracy: 0.7990, Val Loss: 0.6326, Val Accuracy: 0.7650
# Epoch 14/100, Loss: 0.4744, Accuracy: 0.8117, Val Loss: 0.6191, Val Accuracy: 0.7723
# Epoch 15/100, Loss: 0.4423, Accuracy: 0.8302, Val Loss: 0.6242, Val Accuracy: 0.7752
# Epoch 16/100, Loss: 0.4222, Accuracy: 0.8355, Val Loss: 0.6366, Val Accuracy: 0.7825
# Epoch 17/100, Loss: 0.4231, Accuracy: 0.8448, Val Loss: 0.6204, Val Accuracy: 0.7825
# Epoch 18/100, Loss: 0.3782, Accuracy: 0.8501, Val Loss: 0.6245, Val Accuracy: 0.7825
# Epoch 19/100, Loss: 0.3598, Accuracy: 0.8633, Val Loss: 0.6525, Val Accuracy: 0.7781
# Epoch 20/100, Loss: 0.3434, Accuracy: 0.8749, Val Loss: 0.6984, Val Accuracy: 0.7810
# Epoch 21/100, Loss: 0.3227, Accuracy: 0.8813, Val Loss: 0.6462, Val Accuracy: 0.7810
# Epoch 22/100, Loss: 0.3199, Accuracy: 0.8783, Val Loss: 0.6489, Val Accuracy: 0.7737
# Epoch 23/100, Loss: 0.3046, Accuracy: 0.8881, Val Loss: 0.6691, Val Accuracy: 0.7825
# Epoch 24/100, Loss: 0.2975, Accuracy: 0.8925, Val Loss: 0.6443, Val Accuracy: 0.7839
# Epoch 25/100, Loss: 0.2558, Accuracy: 0.9036, Val Loss: 0.6833, Val Accuracy: 0.7825
# Epoch 26/100, Loss: 0.2420, Accuracy: 0.9139, Val Loss: 0.7187, Val Accuracy: 0.7869
# Epoch 27/100, Loss: 0.2367, Accuracy: 0.9041, Val Loss: 0.7089, Val Accuracy: 0.7942
# Epoch 28/100, Loss: 0.2255, Accuracy: 0.9090, Val Loss: 0.7094, Val Accuracy: 0.7912
# Epoch 29/100, Loss: 0.2105, Accuracy: 0.9173, Val Loss: 0.7646, Val Accuracy: 0.7869
# Epoch 30/100, Loss: 0.1965, Accuracy: 0.9163, Val Loss: 0.7906, Val Accuracy: 0.7781
# Epoch 31/100, Loss: 0.2077, Accuracy: 0.9173, Val Loss: 0.7826, Val Accuracy: 0.7737
# Epoch 32/100, Loss: 0.1771, Accuracy: 0.9304, Val Loss: 0.7837, Val Accuracy: 0.7956
# Epoch 33/100, Loss: 0.1660, Accuracy: 0.9338, Val Loss: 0.7983, Val Accuracy: 0.7708
# Epoch 34/100, Loss: 0.1739, Accuracy: 0.9348, Val Loss: 0.8463, Val Accuracy: 0.7898
# Epoch 35/100, Loss: 0.1658, Accuracy: 0.9372, Val Loss: 0.8477, Val Accuracy: 0.7839
# Epoch 36/100, Loss: 0.1546, Accuracy: 0.9426, Val Loss: 0.8492, Val Accuracy: 0.7956
# Epoch 37/100, Loss: 0.1325, Accuracy: 0.9518, Val Loss: 0.9701, Val Accuracy: 0.7839
# Epoch 38/100, Loss: 0.1356, Accuracy: 0.9509, Val Loss: 0.9190, Val Accuracy: 0.8000
# Epoch 39/100, Loss: 0.1286, Accuracy: 0.9494, Val Loss: 0.9101, Val Accuracy: 0.8029
# Epoch 40/100, Loss: 0.1301, Accuracy: 0.9513, Val Loss: 0.9192, Val Accuracy: 0.8058
# Epoch 41/100, Loss: 0.1149, Accuracy: 0.9620, Val Loss: 0.9073, Val Accuracy: 0.7971
# Epoch 42/100, Loss: 0.1093, Accuracy: 0.9577, Val Loss: 1.0179, Val Accuracy: 0.8000
# Epoch 43/100, Loss: 0.1066, Accuracy: 0.9601, Val Loss: 0.9770, Val Accuracy: 0.8029
# Epoch 44/100, Loss: 0.1158, Accuracy: 0.9562, Val Loss: 1.0008, Val Accuracy: 0.7971
# Epoch 45/100, Loss: 0.0999, Accuracy: 0.9650, Val Loss: 1.0406, Val Accuracy: 0.8029
# Epoch 46/100, Loss: 0.1007, Accuracy: 0.9635, Val Loss: 1.0160, Val Accuracy: 0.8029
# Epoch 47/100, Loss: 0.0863, Accuracy: 0.9718, Val Loss: 1.0297, Val Accuracy: 0.8000
# Epoch 48/100, Loss: 0.0949, Accuracy: 0.9669, Val Loss: 1.0503, Val Accuracy: 0.8029
# Epoch 49/100, Loss: 0.0876, Accuracy: 0.9674, Val Loss: 1.0730, Val Accuracy: 0.7898
# Epoch 50/100, Loss: 0.0808, Accuracy: 0.9698, Val Loss: 1.1316, Val Accuracy: 0.8015
# Epoch 51/100, Loss: 0.0815, Accuracy: 0.9674, Val Loss: 1.1131, Val Accuracy: 0.7985
# Epoch 52/100, Loss: 0.0841, Accuracy: 0.9679, Val Loss: 1.1053, Val Accuracy: 0.8029
# Epoch 53/100, Loss: 0.0797, Accuracy: 0.9762, Val Loss: 1.1109, Val Accuracy: 0.8058
# Epoch 54/100, Loss: 0.0833, Accuracy: 0.9742, Val Loss: 1.1149, Val Accuracy: 0.7971
# Epoch 55/100, Loss: 0.0831, Accuracy: 0.9718, Val Loss: 1.0617, Val Accuracy: 0.8044
# Epoch 56/100, Loss: 0.0820, Accuracy: 0.9703, Val Loss: 1.0599, Val Accuracy: 0.8000
# Epoch 57/100, Loss: 0.0770, Accuracy: 0.9723, Val Loss: 1.1117, Val Accuracy: 0.8102
# Epoch 58/100, Loss: 0.0601, Accuracy: 0.9810, Val Loss: 1.1726, Val Accuracy: 0.7971
# Epoch 59/100, Loss: 0.0863, Accuracy: 0.9689, Val Loss: 1.1580, Val Accuracy: 0.8015
# Epoch 60/100, Loss: 0.0542, Accuracy: 0.9820, Val Loss: 1.2162, Val Accuracy: 0.8029
# Epoch 61/100, Loss: 0.0525, Accuracy: 0.9796, Val Loss: 1.2274, Val Accuracy: 0.8073
# Epoch 62/100, Loss: 0.0604, Accuracy: 0.9825, Val Loss: 1.2488, Val Accuracy: 0.7927
# Epoch 63/100, Loss: 0.0413, Accuracy: 0.9849, Val Loss: 1.1958, Val Accuracy: 0.8117
# Epoch 64/100, Loss: 0.0471, Accuracy: 0.9854, Val Loss: 1.2863, Val Accuracy: 0.8102
# Epoch 65/100, Loss: 0.0345, Accuracy: 0.9893, Val Loss: 1.2851, Val Accuracy: 0.8161
# Epoch 66/100, Loss: 0.0394, Accuracy: 0.9873, Val Loss: 1.2816, Val Accuracy: 0.8102
# Epoch 67/100, Loss: 0.0559, Accuracy: 0.9791, Val Loss: 1.2442, Val Accuracy: 0.8117
# Epoch 68/100, Loss: 0.0520, Accuracy: 0.9805, Val Loss: 1.2704, Val Accuracy: 0.8015
# Epoch 69/100, Loss: 0.0551, Accuracy: 0.9815, Val Loss: 1.2797, Val Accuracy: 0.8131
# Epoch 70/100, Loss: 0.0505, Accuracy: 0.9849, Val Loss: 1.3354, Val Accuracy: 0.8131
# Epoch 71/100, Loss: 0.0474, Accuracy: 0.9864, Val Loss: 1.3702, Val Accuracy: 0.8161
# Epoch 72/100, Loss: 0.0365, Accuracy: 0.9869, Val Loss: 1.3300, Val Accuracy: 0.8117
# Epoch 73/100, Loss: 0.0439, Accuracy: 0.9854, Val Loss: 1.2143, Val Accuracy: 0.8161
# Epoch 74/100, Loss: 0.0458, Accuracy: 0.9844, Val Loss: 1.2660, Val Accuracy: 0.7971
# Epoch 75/100, Loss: 0.0576, Accuracy: 0.9757, Val Loss: 1.3109, Val Accuracy: 0.8044
# Epoch 76/100, Loss: 0.0656, Accuracy: 0.9820, Val Loss: 1.3323, Val Accuracy: 0.8117
# Epoch 77/100, Loss: 0.0496, Accuracy: 0.9830, Val Loss: 1.3077, Val Accuracy: 0.8088
# Epoch 78/100, Loss: 0.0534, Accuracy: 0.9830, Val Loss: 1.2602, Val Accuracy: 0.8204
# Epoch 79/100, Loss: 0.0441, Accuracy: 0.9839, Val Loss: 1.4294, Val Accuracy: 0.8117
# Epoch 80/100, Loss: 0.0527, Accuracy: 0.9800, Val Loss: 1.3447, Val Accuracy: 0.8117
# Epoch 81/100, Loss: 0.0570, Accuracy: 0.9786, Val Loss: 1.4182, Val Accuracy: 0.8058
# Epoch 82/100, Loss: 0.0541, Accuracy: 0.9825, Val Loss: 1.2857, Val Accuracy: 0.8146
# Epoch 83/100, Loss: 0.0426, Accuracy: 0.9869, Val Loss: 1.2661, Val Accuracy: 0.8161
# Epoch 84/100, Loss: 0.0332, Accuracy: 0.9898, Val Loss: 1.2836, Val Accuracy: 0.8248
# Epoch 85/100, Loss: 0.0344, Accuracy: 0.9893, Val Loss: 1.3132, Val Accuracy: 0.8146
# Epoch 86/100, Loss: 0.0529, Accuracy: 0.9820, Val Loss: 1.3341, Val Accuracy: 0.8146
# Epoch 87/100, Loss: 0.0368, Accuracy: 0.9888, Val Loss: 1.4157, Val Accuracy: 0.8175
# Epoch 88/100, Loss: 0.0319, Accuracy: 0.9912, Val Loss: 1.4483, Val Accuracy: 0.8102
# Epoch 89/100, Loss: 0.0287, Accuracy: 0.9888, Val Loss: 1.5212, Val Accuracy: 0.8073
# Epoch 90/100, Loss: 0.0285, Accuracy: 0.9922, Val Loss: 1.3797, Val Accuracy: 0.8131
# Epoch 91/100, Loss: 0.0355, Accuracy: 0.9869, Val Loss: 1.2925, Val Accuracy: 0.8102
# Epoch 92/100, Loss: 0.0461, Accuracy: 0.9854, Val Loss: 1.4468, Val Accuracy: 0.7942
# Epoch 93/100, Loss: 0.0353, Accuracy: 0.9873, Val Loss: 1.4677, Val Accuracy: 0.8102
# Epoch 94/100, Loss: 0.0398, Accuracy: 0.9873, Val Loss: 1.4147, Val Accuracy: 0.8131
# Epoch 95/100, Loss: 0.0307, Accuracy: 0.9908, Val Loss: 1.4737, Val Accuracy: 0.8088
# Epoch 96/100, Loss: 0.0202, Accuracy: 0.9946, Val Loss: 1.5260, Val Accuracy: 0.8015
# Epoch 97/100, Loss: 0.0269, Accuracy: 0.9932, Val Loss: 1.5670, Val Accuracy: 0.8088
# Epoch 98/100, Loss: 0.0250, Accuracy: 0.9922, Val Loss: 1.4151, Val Accuracy: 0.8088
# Epoch 99/100, Loss: 0.0248, Accuracy: 0.9927, Val Loss: 1.5149, Val Accuracy: 0.8044
# Epoch 100/100, Loss: 0.0294, Accuracy: 0.9912, Val Loss: 1.5668, Val Accuracy: 0.7985
# Test Loss: 1.2143, Test Accuracy: 0.8134

# %%
print(f'Accuracy of Deep Learning Model is {round(test_acc.detach().numpy()*100,2)}%')
# Out:
# Accuracy of Deep Learning Model is 81.34%

# %% [markdown]
# # Conclusions

# %% [markdown]
# Both random forest and a deep neural net result in very similar accuracy on unseen images. The DNN can be trained for extra epoches but after the 25th epoch the risk of overfitting is starting to show up.
#
# Perhaps this is the plateau with the amount and quality of data we have, but I'll be have to be proven otherwise. For the moment let's wrap this up by trying the model on the items we extracted from the dataset due to the target value missing.

# %%
features = unknown_data.drop(labels=["Lowest distortion"], axis=1)
features_tensor = torch.tensor(features.values.tolist(), dtype=torch.float32)

predictions = model(features_tensor).detach().numpy().argmax(axis=1)
prediction_df = pd.DataFrame(columns=["Compound", "Predicted Structure"])
i = 0
for row in features.iterrows():
    row_index = row[0]
    item_dict = {'Compound': [unprocessed_data.iloc[row_index]["Compound"]], 'Predicted Structure': [class_names[predictions[i]]]}
    item = pd.DataFrame(item_dict)
    prediction_df = pd.concat([prediction_df, item], ignore_index=True)
    i += 1

# %%
prediction_df
# Out:
#    Compound Predicted Structure
# 0    FeLuO3               cubic
# 1    GdCoO3        orthorhombic
# 2    LaNpO3        orthorhombic
# 3    NbNpO3               cubic
# 4    NiNpO3               cubic
# 5    NiOsO3               cubic
# 6    NiTcO3               cubic
# 7    NpCsO3        orthorhombic
# 8     Np2O3               cubic
# 9    OsCaO3               cubic
# 10   PaCsO3        orthorhombic
# 11   PaPuO3               cubic
# 12    PaUO3               cubic
# 13   PuAcO3        orthorhombic
# 14   PuCaO3               cubic
# 15   PuCoO3               cubic
# 16   PuCsO3        orthorhombic
# 17   PuCuO3               cubic
# 18   PuIrO3               cubic
# 19   PuLaO3               cubic
# 20   PuNpO3               cubic
# 21   PuRhO3               cubic
